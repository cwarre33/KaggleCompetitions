# %% [markdown]
# # API Notebook Creator badge
#
# This notebook was **imported/pushed to Kaggle using the Kaggle API** to earn the [API Notebook Creator](https://www.kaggle.com/progression/badges) badge.

# %%
# Pushed via: kaggle kernels push -p api_notebook
print('Notebook created via Kaggle API!')
