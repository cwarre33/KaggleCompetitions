# %% [markdown]
# # EDA - Playground S6E2 Heart Disease
#
# Exploratory analysis and baseline model.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import DATA_RAW, TARGET_COL

# %%
train = pd.read_csv(DATA_RAW / 'train.csv')
test = pd.read_csv(DATA_RAW / 'test.csv')
print('Train shape:', train.shape)
print('Test shape:', test.shape)
print('\nTrain dtypes:')
print(train.dtypes)
print('\nMissing values:')
print(train.isnull().sum())

# %%
print('Target distribution:')
print(train[TARGET_COL].value_counts())
train[TARGET_COL].value_counts().plot(kind='bar')
plt.title('Heart Disease')
plt.show()

# %%
corr = train.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title('Correlation matrix')
plt.tight_layout()
plt.show()

# %%
from src.train import train_baseline

auc, _ = train_baseline(model_type='xgboost', n_folds=5)
print(f'Baseline XGBoost CV ROC AUC: {auc:.4f}')
